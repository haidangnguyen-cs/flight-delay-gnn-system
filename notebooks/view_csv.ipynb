# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

file_path = '../data/processed/flights_final_dataset.csv'
df = pd.read_csv(file_path)

df.head(10)
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0        1      1             1            3  2025-01-01                AA
# 1        1      1             1            3  2025-01-01                AA
# 2        1      1             1            3  2025-01-01                AA
# 3        1      1             1            3  2025-01-01                AA
# 4        1      1             1            3  2025-01-01                AA
# 5        1      1             1            3  2025-01-01                AA
# 6        1      1             1            3  2025-01-01                AA
# 7        1      1             1            3  2025-01-01                AA
# 8        1      1             1            3  2025-01-01                AA
# 9        1      1             1            3  2025-01-01                AA
#
#   TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN       ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# ...
